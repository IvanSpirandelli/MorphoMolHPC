# %%
import Pkg; 

if split(pwd(),"/")[end] == "config_generators"
    cd(joinpath(@__DIR__, "../../"))
    Pkg.activate("Project.toml")
end

using Rotations

function get_energy(id)
    if id == "ZERO"
        return "cc_fsol"
    else
        return "cc_fsol_twasp_interpolated"
    end
end

function get_base_persistence_weights(id)
    pws = Dict(
        "ZERO" => [0.0, 0.0, 0.0],
        "ONE" => [1.0, -0.2, -1.5],
        "TWO" => [1.0, -0.3, -1.2],
        "THREE" => [1.0, -0.4, -0.9],
        "FOUR" => [1.0, -0.7, -0.0],
        "FIVE" => [1.0, -0.7, -0.5],
        "SIX" => [1.0, -0.7, -0.7],
        "SEVEN" => [1.0, 0.0, 0.0],
        "EIGHT" => [1.0, 0.0, -2.0]
    )
    pws[id]
end

top_touching_states = Vector{Tuple{QuatRotation{Float64}, Vector{Float64}}}[[([-0.7317732747065022 0.640932193978558 -0.2317623721555135; -0.6578126381835526 -0.5752376669479247 0.4861935412675692; 0.17829864685777377 0.5082396572938176 0.8425568486948203], [118.19304303738409, 44.63146418204686, 91.2115537081645]), ([-0.11917139754021466 0.9599492545310386 -0.2535657838384674; -0.9780956245425321 -0.06960595899574507 0.1961732900346978; 0.17066671397512498 0.2713898288395991 0.9472172050503237], [99.10643291254962, 46.45977804144794, 73.13503812389071])], [([0.7400141934654972 -0.6219174653826715 0.2561204008305313; 0.6586544672389795 0.592964734730124 -0.46321389891988174; 0.13621044840882957 0.5114797059692751 0.84843103675304], [34.727710181468034, 107.43593361646275, 47.71731956583622]), ([0.6468788741531657 -0.7604026424561852 0.05775416452501311; 0.5512789613805336 0.41395777973928305 -0.724382815459148; 0.5269148213075159 0.500426595954864 0.6869745214689511], [51.78651803946268, 100.81663066825588, 23.92212100933278])], [([-0.20687136937735662 -0.04734382477118099 0.9772219803033341; 0.2022607723250124 -0.9793207642440869 -0.004628250086587418; 0.9572328956478792 0.19669622003589754 0.21216922612189315], [42.95045669757703, 57.13879856688534, 72.63475041698165]), ([-0.5099803760246169 -0.30890878289181767 0.802804696001523; 0.5796376758023676 -0.8129898881673707 0.05538597772042003; 0.6355628850556264 0.49358160985789706 0.5936640578221549], [36.981642946590775, 29.437151611476647, 82.73477635271409])], [([-0.15564141010096666 0.3809359671399604 -0.9114074502663057; -0.9120854077727099 -0.409707688505512 -0.015486087548594318; -0.37930984747284785 0.8288711594202178 0.41121361929234734], [30.98480576351546, 34.934314045079184, 58.79245017690629]), ([0.09326584399203544 0.01499005835660866 -0.9955283926111311; -0.9810972360696699 0.17166401409118995 -0.08932905262308433; 0.16955735230561775 0.9850415039055709 0.030717093979467536], [27.16393856907507, 27.249931492554687, 31.924086779912194])], [([0.3830850598715845 0.6522884553281911 -0.6540379254666637; 0.70748855858651 0.24803894721734715 0.6617677992562668; 0.5938903740357786 -0.7162377061484985 -0.3664666040975227], [17.403645782612884, 40.85686019166892, 84.09830900198098]), ([0.21617540508769723 0.7932
176063; 0.8759781119420218 -0.4779645939556287 0.0649014200407963], [87.88072186849804, 93.75271283715549, 117.45060272324561]), ([-0.9586667926687619 0.25981842788723475 0.11598433154683063; 0.20697605282071163 0.916503854454321 -0.3423179783901232; -0.19524060590183928 -0.30416289928350676 -0.9323980032724782], [98.15005282352705, 74.13386550654319, 104.98554687853452])], [([0.0328251621870038 -0.7170620347668619 0.6962359851540554; -0.752715210817515 0.44055178017424984 0.48921768200799604; -0.657527429185562 -0.5401260661006285 -0.5252823170327731], [107.57930084954862, 71.51048410973672, 97.2810731749952]), ([-0.9753409406542686 0.19752913278126596 0.09844943466763995; 0.02007981921016047 0.5236407389547545 -0.8517025169432436; -0.2197881942784557 -0.8287234871835417 -0.5146946001720011], [109.93538103353947, 51.207372326116584, 113.35386469368176])], [([0.7555918795368677 -0.21728229793717962 -0.6179557545497153; 0.3154918854571103 0.9474683728333624 0.05261703803183679; 0.5740607823120186 -0.23471703279409636 0.7844502104835425], [29.092392362385993, 49.81781058859735, 64.83152274034538]), ([0.8733459127350842 -0.1281883057964145 0.46993050014440774; -0.34031502528923946 0.5296643125190847 0.7769436270451514; -0.34850050254097564 -0.8384649511462813 0.41895575593128825], [29.441530746092702, 78.20016322512164, 61.33543625824418])], [([0.8506156163216958 -0.42019178720901995 0.3160568544293409; -0.46869453673346495 -0.8783855456881313 0.09361764984437881; 0.23828240494397096 -0.227766755889159 -0.9441100573587085], [92.00224247761082, 113.65395484833958, 16.3190542809395]), ([0.42093416435991604 0.7732776431935173 -0.4741899575188387; -0.5042941702897157 -0.23503176968915862 -0.8309316801329752; -0.7539905961525291 0.5888987636036275 0.29102650590572043], [88.87197419332534, 86.56721218476342, 22.55054040032507])]];
# Out:
#   Activating project at `~/Doktor/Code/MorphoMol/MorphoMolHPC`

# %%
cd(joinpath(@__DIR__, "lawrencium_hpc_scripts/config_generators/"))
pwd()
# Out:
# "/Users/ivanspirandelli/Doktor/Code/MorphoMol/MorphoMolHPC/lawrencium_hpc_scripts/config_generators"

# %%
function get_perturbation_and_initialization(energy, mol_type, n_mol)
    if mol_type == "hard_sphere"
        return "single_random_only_translation", "random_only_translation"
    else
        if occursin("cc", energy) && n_mol > 2
            return "single_random_get_index", "random"
        else 
            return "single_random", "random"
        end
    end
end

mol_type = "6r7m"

delaunay_eps = 100.0
overlap_jump = 0.0
overlap_slope = 1.1
rs = 1.4
η = 0.3665
exact_delaunay = mol_type == "6r7m" ? "false" : "true"

T_search_runs = 0
T_search_time = 0.0

mode = "iterations"
iterations = 10000
simulation_time_minutes = 1.0 #6.0 * 60.0
algorithm = "rwm"
mu = 0.5

#sa_level = "[1.0,0.8,0.6,0.4,0.2]"
sa_level = "[0.0]"

n_mol = 2

id = "ZERO"
temperature = 3.0

energy = get_energy(id)

bnds = 120.0

perturbation, initialization = get_perturbation_and_initialization(energy, mol_type, n_mol)

σ_r = 0.2
σ_t = 1.25
# Out:
# 1.25

# %%
persistence_weights = get_base_persistence_weights(id)
persistence_weights = "[$(persistence_weights[1]),$(persistence_weights[2]),$(persistence_weights[3])]" 
comment = "ma_touch_ma_finish"
comment = replace(comment, " " => "_")
simulations_per_combination = 1

input_specifier = "$(comment)"
output_directory = "../Simulations/unsorted_output/$(input_specifier)/"
open("../configs/$(input_specifier)_config.txt", "w") do io
    println(io,"ArrayTaskID input_string")
    output_directory = "../Simulations/unsorted_output/$(input_specifier)/"
    i = 1
    for state in ma_touching_states
        for _ in 0:simulations_per_combination-1
            name = "$(i)"
            input_string = escape_string("name=\"$name\";x=$(state);temperature=$(temperature);alg=\"$(algorithm)\";sa_level=$(sa_level);T_search_runs=$(T_search_runs);T_search_time=$(T_search_time);rs=$rs;η=$η;σ_t=$σ_t;σ_r=$σ_r;mu=$(mu);overlap_jump=$overlap_jump;overlap_slope=$overlap_slope;bnds=$bnds;persistence_weights=$persistence_weights;n_mol=$n_mol;mol_type=\"$mol_type\";nrg=\"$energy\";prtbt=\"$perturbation\";intl=\"$initialization\";output_directory=\"$output_directory\";delaunay_eps=$delaunay_eps;exact_delaunay=$exact_delaunay;comment=\"$comment\";mode=\"$(mode)\";iterations=$(iterations);simulation_time_minutes=$simulation_time_minutes")
            println(io, "$i $input_string")
            i += 1
        end
    end
end
total_simulations = length(readlines("../configs/$(input_specifier)_config.txt")) - 1

total_time_needed = simulation_time_minutes + (T_search_runs * T_search_time)

hours = Int(round(total_time_needed / 60.0))
days = hours ÷ 24
remaining_hours = hours % 24
remaining_hours_string = remaining_hours < 10 ? "0$(remaining_hours)" : string(remaining_hours)
buffer_time_string = total_time_needed < 5 ? "0$(Int(round(total_time_needed))+2)" : "30"

open("../$(input_specifier)_script.job", "w") do io
    println(io, "#!/bin/bash")
    println(io, "#SBATCH --job-name=SolvationSimulations")
    println(io, "#SBATCH --time=0$(days)-$(remaining_hours_string):$(buffer_time_string)")
    println(io, "#SBATCH --ntasks=1")
    println(io, "#SBATCH --cpus-per-task=1")
    println(io, "#SBATCH --mem-per-cpu=1G")
    println(io, "#SBATCH --array=1-$(total_simulations)")
    println(io, "#SBATCH --chdir=\$SCRATCH/MorphoMolHPC/")
    println(io, "#SBATCH -o ./job_log/$(input_specifier)/%a.out # STDOUT")
    println(io, "")
    println(io, "module purge")
    println(io, "module load anaconda3/2024.02-1-11.4")    
    println(io, "conda activate oineus_venv")
    println(io, "module load julia/1.10.2-11.4")    
    println(io, "")
    println(io, "# Specify the path to the config file")
    println(io, "config=lawrencium_hpc_scripts/configs/$(input_specifier)_config.txt")
    println(io, "")
    println(io, "# Extract the variables from config file")
    println(io, "config_string=\$(awk -v ArrayTaskID=\$SLURM_ARRAY_TASK_ID '\$1==ArrayTaskID {print \$2}' \$config)")
    println(io, "")
    println(io, "julia -e \"$(escape_string("include(\"julia_scripts/generic_call.jl\"); generic_call(\"\$config_string\")"))\"")
end
